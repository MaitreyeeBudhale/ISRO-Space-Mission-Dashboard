# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'../data/cleaned/isro_mission_launches_cleaned.csv')
df.head()
# Out:
#    SL No                             Name Launch Date   Launch Vehicle  \
# 0      1                        Aryabhata  1975-04-19  C-1 Intercosmos
# 1      2                       Bhaskara-I  1979-06-07   C-1Intercosmos
# 2      2                       Bhaskara-I  1979-06-07   C-1Intercosmos
# 3      3  Rohini Technology Payload (RTP)  1979-08-10          SLV-3E1
# 4      4            Rohini Satellite RS-1  1980-07-18          SLV-3E2
#
#               Orbit Type        Application              Remarks
# 0                No Data       Experimental    Launch successful
# 1  LEO (Low Earth Orbit)  Earth Observation    Launch successful
# 2  LEO (Low Earth Orbit)       Experimental    Launch successful
# 3                No Data            No Data  Launch unsuccessful
# 4                No Data            No Data    Launch successful

# %%
df['Application'].unique()
# Out:
# array(['Experimental', 'Earth Observation', 'No Data', 'Communication',
#        'Climate & Environment', 'Planetary Observation',
#        'Student Satellite', 'Navigation', 'Disaster Management System',
#        'Space Science', 'Formation Flying(Technology Demonstration)',
#        'In-orbit Docking Experiment', 'Earth Observation(Radar)'],
#       dtype=object)

# %%
df['Application'].value_counts()
# Out:
# Application
# Earth Observation                             46
# Communication                                 45
# Experimental                                  15
# Navigation                                    14
# Climate & Environment                          9
# Disaster Management System                     5
# Planetary Observation                          5
# No Data                                        4
# Student Satellite                              1
# Space Science                                  1
# Formation Flying(Technology Demonstration)     1
# In-orbit Docking Experiment                    1
# Earth Observation(Radar)                       1
# Name: count, dtype: int64

# %%
applications=df['Application'].unique()
count_of_applications=df['Application'].value_counts()
application_labels=count_of_applications.index.tolist()
count_by_application=count_of_applications.values.tolist()
xs=[i+1.5 for i in range(len(applications))]
applications
plt.figure(figsize=(14,6))
plt.bar(xs,count_by_application)
plt.xticks(xs,application_labels,rotation=90)
plt.show()

# %%
remarks=df['Remarks'].unique()
count_of_remarks=df['Remarks'].value_counts()
remark_labels=count_of_remarks.index.tolist()
count_by_remark=count_of_remarks.values.tolist()
# xs=[i+1.5 for i in range(len(remarks))]
count_by_remark
plt.figure(figsize=(14,7))
plt.pie(count_by_remark,labels=remark_labels,explode=[0.1,0.2,0.2,0.1,0.1],rotatelabels=90,startangle=45)
# plt.xticks(xs,remark_labels,rotation=90)
plt.show()

# %%
df['Launch Date']=pd.to_datetime(df['Launch Date'])

# %%
year_groups=df.groupby('Launch Date').size()
plt.figure(figsize=(14,6))
year_groups.plot(kind='line')
plt.show()

# %%
df['Orbit Type'].value_counts()
# Out:
# Orbit Type
# GSO (Geosynchronous Orbit)             48
# SSPO (Sun Synchronous Polar Orbit)     40
# No Data                                22
# LEO (Low Earth Orbit)                  14
# GEO                                     9
# GTO (Geosynchronous Transfer Orbit)     7
# Lunar                                   4
# SSO (Sun Synchronous Orbit)             2
# Martian                                 1
# HEO(High Elliptical Orbit)              1
# Name: count, dtype: int64

# %%
orbit_type_counts=df['Orbit Type'].value_counts()
orbit_type_labels=orbit_type_counts.index.tolist()
xs_orbit_type=[i+0.5 for i in range(len(orbit_type_counts))]
y_orbit_count=orbit_type_counts.values
plt.figure(figsize=(14,6))
plt.bar(xs_orbit_type,y_orbit_count)
plt.xticks(xs_orbit_type,orbit_type_labels,rotation=90)
plt.show()
